# %%
# !pip install numpy==1.23.5 frechet_audio_distance
# Out:
# ...
# INFO: pip is looking at multiple versions of frechet-audio-distance to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
np.__version__
# Out:
# '1.23.5'

# %%
from frechet_audio_distance import FrechetAudioDistance

frechet = FrechetAudioDistance(
    model_name="vggish",
    sample_rate=16000,
    use_pca=False,
    use_activation=False,
    verbose=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/harritaylor/torchvggish/zipball/master" to /root/.cache/torch/hub/master.zip
# Downloading: "https://github.com/harritaylor/torchvggish/releases/download/v0.1/vggish-10086976.pth" to /root/.cache/torch/hub/checkpoints/vggish-10086976.pth
# 100%|██████████| 275M/275M [00:01<00:00, 174MB/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/diploma_data/samples/transformer_samples.zip -d baseline_transformer/
# !unzip /content/drive/MyDrive/diploma_data/samples/groove_original.zip -d groove_original/
# !unzip /content/drive/MyDrive/diploma_data/samples/groove_decoded.zip -d groove_decoded/
# !unzip /content/drive/MyDrive/diploma_data/samples/topotransformer_samples_100.zip -d topo_transformer_small/
# !unzip /content/drive/MyDrive/diploma_data/samples/topotransformer_samples.zip -d topo_transformer/
# Out:
# Archive:  /content/drive/MyDrive/diploma_data/wavs.zip
#   inflating: baseline_transformer/sample587.wav
#   inflating: baseline_transformer/sample101.wav
#   inflating: baseline_transformer/sample379.wav
#   inflating: baseline_transformer/sample625.wav
#   inflating: baseline_transformer/sample475.wav
#   inflating: baseline_transformer/sample219.wav
#   inflating: baseline_transformer/sample984.wav
#   inflating: baseline_transformer/sample209.wav
#   inflating: baseline_transformer/sample39.wav
#   inflating: baseline_transformer/sample16.wav
#   inflating: baseline_transformer/sample800.wav
#   inflating: baseline_transformer/sample129.wav
#   inflating: baseline_transformer/sample41.wav
#   inflating: baseline_transformer/sample783.wav
#   inflating: baseline_transformer/sample806.wav
#   inflating: baseline_transformer/sample448.wav
#   inflating: baseline_transformer/sample710.wav
#   inflating: baseline_transformer/sample896.wav
# ...

# %%
fad_score = frechet.score(
    "/content/groove_original",
    "/content/groove_decoded",
    dtype="float32"
)
print(fad_score)
# Out:
# 2.04530260119248

# %%
fad_score = frechet.score(
    "/content/groove_original",
    "/content/baseline_transformer",
    dtype="float32"
)
print(fad_score)
# Out:
# 4.612797726663033

# %%
fad_score = frechet.score(
    "/content/groove_original",
    "/content/topo_transformer",
    dtype="float32"
)
print(fad_score)
# Out:
# 5.302451602096866

# %%
fad_score = frechet.score(
    "/content/groove_original",
    "/content/topo_transformer_small",
    dtype="float32"
)
print(fad_score)
# Out:
# 5.453410214007659
